# %% [markdown]
# https://medium.com/@pranay.janupalli/understanding-sinusoidal-positional-encoding-in-transformers-26c4c161b7cc

# %%
import torch
import math

# %%
# Define the positional encoding function
def positional_encoding(length, d_model):
    pe = torch.zeros(length, d_model)
    for pos in range(length):
        for i in range(0, d_model, 2):
            pe[pos, i] = math.sin(pos / (10000 ** ((2 * i) / d_model)))
            if i + 1 < d_model:
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * i) / d_model)))
    return pe

# Define the parameters
length = 16  # The number of positions (sequence length)
d_model = 32  # The dimension of the embedding vector

# Calculate positional encodings
positional_encodings = positional_encoding(length, d_model)

# Print the positional encodings
print("Positional Encodings:\n", positional_encodings)
# Out:
# Positional Encodings:
#  tensor([[ 0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,
#           0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,
#           0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,
#           0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000],
#         [ 0.8415,  0.5403,  0.6816,  0.7318,  0.5332,  0.8460,  0.4093,  0.9124,
#           0.3110,  0.9504,  0.2349,  0.9720,  0.1769,  0.9842,  0.1330,  0.9911,
#           0.0998,  0.9950,  0.0749,  0.9972,  0.0562,  0.9984,  0.0422,  0.9991,
#           0.0316,  0.9995,  0.0237,  0.9997,  0.0178,  0.9998,  0.0133,  0.9999],
#         [ 0.9093, -0.4161,  0.9975,  0.0709,  0.9021,  0.4315,  0.7469,  0.6649,
#           0.5911,  0.8066,  0.4567,  0.8896,  0.3482,  0.9374,  0.2636,  0.9646,
#           0.1987,  0.9801,  0.1494,  0.9888,  0.1122,  0.9937,  0.0842,  0.9964,
#           0.0632,  0.9980,  0.0474,  0.9989,  0.0356,  0.9994,  0.0267,  0.9996],
#         [ 0.1411, -0.9900,  0.7783, -0.6279,  0.9933, -0.1160,  0.9536,  0.3010,
#           0.8126,  0.5828,  0.6529,  0.7574,  0.5085,  0.8610,  0.3895,  0.9210,
#           0.2955,  0.9553,  0.2231,  0.9748,  0.1679,  0.9858,  0.1262,  0.9920,
#           0.0947,  0.9955,  0.0711,  0.9975,  0.0533,  0.9986,  0.0400,  0.9992],
#         [-0.7568, -0.6536,  0.1415, -0.9899,  0.7785, -0.6277,  0.9933, -0.1157,
#           0.9536,  0.3011,  0.8126,  0.5829,  0.6528,  0.7575,  0.5085,  0.8611,
#           0.3894,  0.9211,  0.2955,  0.9553,  0.2230,  0.9748,  0.1679,  0.9858,
#           0.1262,  0.9920,  0.0947,  0.9955,  0.0711,  0.9975,  0.0533,  0.9986],
#         [-0.9589,  0.2837, -0.5711, -0.8209,  0.3239, -0.9461,  0.8589, -0.5122,
#           0.9999, -0.0103,  0.9268,  0.3757,  0.7765,  0.6301,  0.6184,  0.7858,
#           0.4794,  0.8776,  0.3662,  0.9305,  0.2775,  0.9607,  0.2093,  0.9779,
#           0.1575,  0.9875,  0.1183,  0.9930,  0.0888,  0.9960,  0.0666,  0.9978],
#         [-0.2794,  0.9602, -0.9774, -0.2114, -0.2304, -0.9731,  0.5740, -0.8188,
#           0.9471, -0.3208,  0.9891,  0.1474,  0.8757,  0.4828,  0.7174,  0.6966,
#           0.5646,  0.8253,  0.4349,  0.9005,  0.3310,  0.9436,  0.2503,  0.9682,
#           0.1886,  0.9821,  0.1418,  0.9899,  0.1065,  0.9943,  0.0799,  0.9968],
#         [ 0.6570,  0.7539, -0.8593,  0.5114, -0.7137, -0.7004,  0.1886, -0.9821,
#           0.8004, -0.5994,  0.9960, -0.0890,  0.9473,  0.3203,  0.8037,  0.5951,
#           0.6442,  0.7648,  0.5011,  0.8654,  0.3836,  0.9235,  0.2909,  0.9567,
#           0.2196,  0.9756,  0.1652,  0.9863,  0.1242,  0.9923,  0.0932,  0.9956],
#         [ 0.9894, -0.1455, -0.2802,  0.9599, -0.9773, -0.2120, -0.2299, -0.9732,
#           0.5743, -0.8186,  0.9472, -0.3205,  0.9890,  0.1476,  0.8757,  0.4829,
#           0.7174,  0.6967,  0.5646,  0.8254,  0.4349,  0.9005,  0.3310,  0.9436,
#           0.2503,  0.9682,  0.1886,  0.9821,  0.1418,  0.9899,  0.1065,  0.9943],
#         [ 0.4121, -0.9111,  0.4492,  0.8934, -0.9398,  0.3417, -0.6081, -0.7939,
#           0.2913, -0.9566,  0.8454, -0.5341,  0.9996, -0.0297,  0.9321,  0.3622,
#           0.7833,  0.6216,  0.6248,  0.7808,  0.4848,  0.8746,  0.3705,  0.9288,
#           0.2808,  0.9598,  0.2118,  0.9773,  0.1594,  0.9872,  0.1197,  0.9928],
#         [-0.5440, -0.8391,  0.9376,  0.3476, -0.6129,  0.7901, -0.8798, -0.4754,
#          -0.0207, -0.9998,  0.6963, -0.7178,  0.9786, -0.2060,  0.9720,  0.2351,
#           0.8415,  0.5403,  0.6816,  0.7318,  0.5332,  0.8460,  0.4093,  0.9124,
#           0.3110,  0.9504,  0.2349,  0.9720,  0.1769,  0.9842,  0.1330,  0.9911],
#         [-1.0000,  0.0044,  0.9231, -0.3847, -0.0973,  0.9953, -0.9973, -0.0737,
#          -0.3306, -0.9438,  0.5082, -0.8612,  0.9267, -0.3758,  0.9946,  0.1037,
#           0.8912,  0.4536,  0.7345,  0.6786,  0.5799,  0.8147,  0.4474,  0.8943,
#           0.3409,  0.9401,  0.2579,  0.9662,  0.1944,  0.9809,  0.1462,  0.9893],
#         [-0.5366,  0.8439,  0.4133, -0.9106,  0.4483,  0.8939, -0.9401,  0.3410,
#          -0.6077, -0.7942,  0.2916, -0.9565,  0.8456, -0.5338,  0.9996, -0.0294,
#           0.9320,  0.3624,  0.7832,  0.6217,  0.6247,  0.7808,  0.4847,  0.8747,
#           0.3704,  0.9289,  0.2807,  0.9598,  0.2118,  0.9773,  0.1593,  0.9872],
#         [ 0.4202,  0.9074, -0.3182, -0.9480,  0.8559,  0.5172, -0.7181,  0.6959,
#          -0.8245, -0.5658,  0.0588, -0.9983,  0.7378, -0.6750,  0.9868, -0.1621,
#           0.9636,  0.2675,  0.8276,  0.5613,  0.6676,  0.7445,  0.5212,  0.8535,
#           0.3996,  0.9167,  0.3034,  0.9529,  0.2291,  0.9734,  0.1725,  0.9850],
#         [ 0.9906,  0.1367, -0.8790, -0.4768,  0.9998, -0.0188, -0.3704,  0.9289,
#          -0.9596, -0.2813, -0.1774, -0.9841,  0.6068, -0.7949,  0.9565, -0.2918,
#           0.9854,  0.1700,  0.8673,  0.4977,  0.7084,  0.7058,  0.5567,  0.8307,
#           0.4284,  0.9036,  0.3259,  0.9454,  0.2464,  0.9692,  0.1856,  0.9826],
#         [ 0.6503, -0.7597, -0.9682,  0.2502,  0.8358, -0.5490,  0.0422,  0.9991,
#          -0.9995,  0.0310, -0.4036, -0.9149,  0.4566, -0.8897,  0.9092, -0.4164,
#           0.9975,  0.0707,  0.9022,  0.4313,  0.7470,  0.6648,  0.5912,  0.8065,
#           0.4568,  0.8896,  0.3483,  0.9374,  0.2636,  0.9646,  0.1987,  0.9801]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert positional encodings to a NumPy array for visualization
positional_encodings_np = positional_encodings.numpy()

# Plot the heatmap using Seaborn
plt.figure(figsize=(10, 6))
sns.heatmap(positional_encodings_np, cmap="viridis", annot=False)
# sns.heatmap(positional_encodings_np, cmap="viridis", annot=True, fmt=".2f", cbar=True)
plt.title("Positional Encodings Heatmap")
plt.xlabel("Embedding Dimension")
plt.ylabel("Sequence Position")
plt.show()
